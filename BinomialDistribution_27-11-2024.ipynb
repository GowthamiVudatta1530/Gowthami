# %% [markdown]
# <a href="https://colab.research.google.com/github/GowthamiVudatta1530/Gowthami/blob/DAY-1/Day-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv('/content/AllCounts_V_4_1.csv')

# %%
x
# Out:
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# 5173   Zig Zag Island    ZIGZ          48.1              -59.842
#
#       latitude_epsg_4326        common_name   day  month  year  \
# 0                -60.761     adelie penguin   NaN    NaN  1993
# ...

# %%
import matplotlib.pyplot as plt

x_values=x['longitude_epsg_4326']
y_values=x['latitude_epsg_4326']

plt.scatter(x_values,y_values)

# %%
plt.plot(x_values, y_values)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='longitude_epsg_4326', ylabel='latitude_epsg_4326'>

# %%
sns.histplot(x=y_values)
# Out:
# <Axes: xlabel='latitude_epsg_4326', ylabel='Count'>

# %%
sns.barplot(x=x_values, y=y_values)
plt.show()

# %%
sns.lineplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='longitude_epsg_4326', ylabel='latitude_epsg_4326'>

# %%
import scipy.stats as stats
# Number of trials
n = 10

# Probability of success
p = 0.5

# Calculate x-axis values (number of successes from 0 to n)
x_values = np.arange(0, n + 1)

# Calculate PMF directly using binom.pmf
y_values = stats.binom.pmf(x_values, n, p)

# Create the plot
plt.bar(x_values, y_values)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution PMF')
plt.show()

# %%
import seaborn as sns

import pandas as pd

import numpy as np



# Sample DataFrame

df = pd.DataFrame(np.random.randn(10, 5), columns=['A', 'B', 'C', 'D', 'E'])



corr_matrix = df.corr()

sns.heatmap(corr_matrix, annot=True)

plt.title('Correlation Matrix')

plt.show()
