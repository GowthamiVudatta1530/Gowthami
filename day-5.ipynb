# %% [markdown]
# <a href="https://colab.research.google.com/github/GowthamiVudatta1530/Gowthami/blob/DAY-1/day-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
df = pd.read_csv('/content/AllCounts_V_4_1.csv')

# %%
df
# Out:
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# 5173   Zig Zag Island    ZIGZ          48.1              -59.842
#
#       latitude_epsg_4326        common_name   day  month  year  \
# 0                -60.761     adelie penguin   NaN    NaN  1993
# ...

# %%
df.isnull().sum()
# Out:
# site_name                 0
# site_id                   0
# cammlr_region             0
# longitude_epsg_4326       0
# latitude_epsg_4326        0
# common_name               0
# day                    2088
# month                  1498
# year                      0
# season_starting           0
# penguin_count            18
# accuracy                 18
# count_type                0
# vantage                 297
# reference                 0
# dtype: int64

# %%
missing_value=["Nan","N/a","na",np.nan]
df = pd.read_csv('/content/AllCounts_V_4_1.csv',na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# site_name                 0
# site_id                   0
# cammlr_region             0
# longitude_epsg_4326       0
# latitude_epsg_4326        0
# common_name               0
# day                    2088
# month                  1498
# year                      0
# season_starting           0
# penguin_count            18
# accuracy                 18
# count_type                0
# vantage                 297
# reference                 0
# dtype: int64

# %%
df.isnull().any()
# Out:
# site_name              False
# site_id                False
# cammlr_region          False
# longitude_epsg_4326    False
# latitude_epsg_4326     False
# common_name            False
# day                     True
# month                   True
# year                   False
# season_starting        False
# penguin_count           True
# accuracy                True
# count_type             False
# vantage                 True
# reference              False
# dtype: bool

# %%
df
# Out:
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# 5173   Zig Zag Island    ZIGZ          48.1              -59.842
#
#       latitude_epsg_4326        common_name   day  month  year  \
# 0                -60.761     adelie penguin   NaN    NaN  1993
# ...

# %%
df.dropna(how='all')
# Out:
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# 5173   Zig Zag Island    ZIGZ          48.1              -59.842
#
#       latitude_epsg_4326        common_name   day  month  year  \
# 0                -60.761     adelie penguin   NaN    NaN  1993
# ...

# %%
df.fillna(0)
# Out:
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# 5173   Zig Zag Island    ZIGZ          48.1              -59.842
#
#       latitude_epsg_4326        common_name   day  month  year  \
# 0                -60.761     adelie penguin   0.0    0.0  1993
# ...

# %%
df.fillna(method='bfill' )
# Out:
# <ipython-input-37-5d31ea824cd6>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill' )
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# ...

# %%
df
# Out:
#             site_name site_id cammlr_region  longitude_epsg_4326  \
# 0        Acuna Island    ACUN          48.2              -44.637
# 1        Acuna Island    ACUN          48.2              -44.637
# 2        Acuna Island    ACUN          48.2              -44.637
# 3        Acuna Island    ACUN          48.2              -44.637
# 4        Acuna Island    ACUN          48.2              -44.637
# ...               ...     ...           ...                  ...
# 5169  Zawadski Stacks    ZAWA          48.1              -58.784
# 5170  Zawadski Stacks    ZAWA          48.1              -58.784
# 5171       Zed Island    ZEDI          48.1              -60.166
# 5172       Zed Island    ZEDI          48.1              -60.166
# 5173   Zig Zag Island    ZIGZ          48.1              -59.842
#
#       latitude_epsg_4326        common_name   day  month  year  \
# 0                -60.761     adelie penguin   NaN    NaN  1993
# ...

# %%
df.day.fillna(df.day.mean())
# Out:
# 0       15.372975
# 1       15.372975
# 2       15.372975
# 3       25.000000
# 4       28.000000
#           ...
# 5169    15.372975
# 5170    15.372975
# 5171     2.000000
# 5172    29.000000
# 5173    21.000000
# Name: day, Length: 5174, dtype: float64

# %%
df.day.fillna(df.month.median())
# Out:
# 0       10.0
# 1       10.0
# 2       10.0
# 3       25.0
# 4       28.0
#         ...
# 5169    10.0
# 5170    10.0
# 5171     2.0
# 5172    29.0
# 5173    21.0
# Name: day, Length: 5174, dtype: float64

# %%
	df.penguin_count.fillna(df.penguin_count.mode())
# Out:
# 0        2008.0
# 1        1920.0
# 2        1880.0
# 3        3079.0
# 4        4000.0
#          ...
# 5169      450.0
# 5170       68.0
# 5171     8000.0
# 5172    20000.0
# 5173     1000.0
# Name: penguin_count, Length: 5174, dtype: float64

# %%
df.accuracy.fillna(df.accuracy.median())
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       5.0
# 4       4.0
#        ...
# 5169    2.0
# 5170    1.0
# 5171    4.0
# 5172    5.0
# 5173    5.0
# Name: accuracy, Length: 5174, dtype: float64

# %%
df.vantage.fillna(method='bfill' )
# Out:
# <ipython-input-53-45b468fcfe7d>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.vantage.fillna(method='bfill' )
# 0                ground
# 1                ground
# 2                ground
# 3                   vhr
# 4                ground
#              ...
# 5169             ground
# 5170                uav
# 5171    offshore vessel
# 5172                vhr
# 5173             ground
# Name: vantage, Length: 5174, dtype: object

# %%
df.day.fillna(df.day.mean())
df.day.fillna(df.month.median())
df.penguin_count.fillna(df.penguin_count.mode())
df.accuracy.fillna(df.accuracy.median())
df.vantage.fillna(method='bfill' )
# Out:
# <ipython-input-54-44bbcd615b7e>:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.vantage.fillna(method='bfill' )
# 0                ground
# 1                ground
# 2                ground
# 3                   vhr
# 4                ground
#              ...
# 5169             ground
# 5170                uav
# 5171    offshore vessel
# 5172                vhr
# 5173             ground
# Name: vantage, Length: 5174, dtype: object

# %%
import pandas as pd

# Assuming your data is in a CSV file named 'data.csv'
df = pd.read_csv('/content/AllCounts_V_4_1.csv')  # Replace 'data.csv' with your actual file path

# Now you can use df:
df.accuracy.fillna(df.accuracy.median())
df.vantage.fillna(method='bfill' )
df.day.fillna(df.day.mean())
df.day.fillna(df.month.median())
df.penguin_count.fillna(df.penguin_count.mode())

df.describe()
# Out:
# <ipython-input-12-aaa43d111117>:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.vantage.fillna(method='bfill' )
#        longitude_epsg_4326  latitude_epsg_4326          day        month  \
# count          5174.000000         5174.000000  3086.000000  3676.000000
# mean            -12.443453          -65.796732    15.372975     6.735854
# std              86.602659            4.501344     8.645995     5.247364
# min            -157.700000          -77.710000     1.000000     1.000000
# 25%             -62.673000          -66.874000     8.000000     1.000000
# 50%             -58.775000          -64.765000    15.000000    10.000000
# 75%              39.250000          -62.458000    23.000000    12.000000
# max             171.169000          -60.554000    31.000000    12.000000
#
#               year  season_starting  penguin_count     accuracy
# ...

# %%
import seaborn as sns
sns.displot(df['common_name'])

# %%
sns.boxplot(df['day'])
# Out:
# <Axes: ylabel='day'>
