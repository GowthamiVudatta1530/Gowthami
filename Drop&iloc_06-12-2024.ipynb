# %% [markdown]
# <a href="https://colab.research.google.com/github/GowthamiVudatta1530/Gowthami/blob/DAY-1/Drop%26iloc_06-12-2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets

# %%
import datasets as od

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/archive.zip')

# %%
data
# Out:
#      StudentID                 Name  Age                          Email  \
# 0         3336         David Palmer   19             sean43@hotmail.com
# 1         8774         Andrew Roach   23             vbecker@harvey.com
# 2         1396    Jonathan Gonzalez   22           hollydavis@gmail.com
# 3         6716       Kenneth Morrow   24  ganderson@wheeler-atkins.info
# 4         8830     Kaitlyn Martinez   18           hayesdiane@gmail.com
# ..         ...                  ...  ...                            ...
# 195       3274  Catherine Velasquez   22              fsutton@gmail.com
# 196       3609         Joyce Thomas   19          zanderson@barrera.net
# 197       9179       Theresa Hughes   21             mstanley@yahoo.com
# 198       4463        Steven Golden   19             nvasquez@yahoo.com
# 199       6178     Miss April Smith   20       logansanchez@manning.com
#
#            Department   GPA  GraduationYear
# 0         Mathematics  3.16            2026
# ...

# %%
# Drop the first row of the DataFrame using the integer position
data = data.drop(data.index[0])
#OR
# Reset the index to default integer values before dropping
data = data.reset_index(drop=True)
data = data.drop(index=0)
data
# Out:
#      StudentID                 Name  Age        Department  GraduationYear
# 1         5305         Tiffany Wolf   23       Mathematics            2029
# 2         5048          James Reyes   20         Chemistry            2029
# 3         5986     Samantha Sellers   20       Mathematics            2025
# 4         8721          Michael Kim   25  Computer Science            2027
# 5         6622          Emily Davis   18           Physics            2030
# ..         ...                  ...  ...               ...             ...
# 191       3274  Catherine Velasquez   22           Physics            2025
# 192       3609         Joyce Thomas   19         Chemistry            2030
# 193       9179       Theresa Hughes   21       Mathematics            2025
# 194       4463        Steven Golden   19  Computer Science            2025
# 195       6178     Miss April Smith   20       Mathematics            2028
#
# [195 rows x 5 columns]

# %%
# prompt: Using dataframe data: DROP AXIS=1

# Drop the specified column(s)
# Assuming 'AXIS=1' means dropping a column.  If you meant something else, please clarify.
data.drop('Department', axis=1) # Example: dropping the 'Email' column. Replace with your desired column name(s).

# Display the updated dataframe to confirm the change (optional)
# data
# Out:
#      StudentID                 Name  Age  GraduationYear
# 0         3336         David Palmer   19            2026
# 1         8774         Andrew Roach   23            2027
# 2         1396    Jonathan Gonzalez   22            2027
# 3         6716       Kenneth Morrow   24            2029
# 4         8830     Kaitlyn Martinez   18            2025
# ..         ...                  ...  ...             ...
# 195       3274  Catherine Velasquez   22            2025
# 196       3609         Joyce Thomas   19            2030
# 197       9179       Theresa Hughes   21            2025
# 198       4463        Steven Golden   19            2025
# 199       6178     Miss April Smith   20            2028
#
# [200 rows x 4 columns]

# %%
first_rows_cols = data.iloc[:5, :3]
first_rows_cols
# Out:
#    StudentID               Name  Age
# 0       3336       David Palmer   19
# 1       8774       Andrew Roach   23
# 2       1396  Jonathan Gonzalez   22
# 3       6716     Kenneth Morrow   24
# 4       8830   Kaitlyn Martinez   18

# %%
print(data.loc[0:100,['Name','Age','Email']])
# Out:
#                   Name  Age                          Email
# 0         David Palmer   19             sean43@hotmail.com
# 1         Andrew Roach   23             vbecker@harvey.com
# 2    Jonathan Gonzalez   22           hollydavis@gmail.com
# 3       Kenneth Morrow   24  ganderson@wheeler-atkins.info
# 4     Kaitlyn Martinez   18           hayesdiane@gmail.com
# ..                 ...  ...                            ...
# 96         Joe Bernard   21        kimberly88@herring.info
# 97   Brittany Hamilton   21           smithkaren@yahoo.com
# 98        Maria Rogers   20      reneemartinez@hotmail.com
# 99      Rebecca Miller   23      michaelconner@hotmail.com
# 100    Bryan Velazquez   25              bpowell@gmail.com
#
# [101 rows x 3 columns]

# %% [markdown]
# df.loc data frame function is used to locate and print the columns and rows in this we have to give input as number how many no of rows we want and we have to specify the column names what we are  neded to print for ex:- i need to print first 100  member  data with name age and email  i  wrote the function print(data.loc[0:100,['Name','Age','Email']])

# %%
print(data.loc[5:10,['Name','Department','GPA']])
# Out:
#                 Name        Department   GPA
# 5       Tiffany Wolf       Mathematics  3.30
# 6        James Reyes         Chemistry  2.44
# 7   Samantha Sellers       Mathematics  3.44
# 8        Michael Kim  Computer Science  3.27
# 9        Emily Davis           Physics  3.09
# 10        Adam Evans           Physics  3.42

# %%
print(data.iloc[:3, :4])
# Out:
#    StudentID               Name  Age                 Email
# 0       3336       David Palmer   19    sean43@hotmail.com
# 1       8774       Andrew Roach   23    vbecker@harvey.com
# 2       1396  Jonathan Gonzalez   22  hollydavis@gmail.com

# %% [markdown]
# df.iloc data frame function is used to locate and print the columns and rows in this we have to give as  particular number that means by using indexing we can give numbering how many rows and how many columns we need don't need to give  any column names here
